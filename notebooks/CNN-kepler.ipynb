# %% [markdown]
# # CNN

# %%
import tensorflow as tf
from tensorflow import keras
import stella
import glob
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
# %load_ext tensorboard
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# /Users/azib/micromamba/envs/nets2/lib/python3.8/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /Users/azib/.lightkurve/cache. Please move all the files in the legacy directory /Users/azib/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(

# %%
cadences = 240
frac_balance = 0.67

# %%
# exoplanets = stella.FlareDataSet(fn_dir='/Users/azib/Documents/open_source/nets2/models/exoplanets1k/',
#                          catalog='/Users/azib/Documents/open_source/nets2/catalogs/exoplanets1k.txt',cadences=cadences,frac_balance=1)

# %%
# fbinaries = stella.FlareDataSet(fn_dir='/Users/azib/Documents/open_source/nets2/models/binaries1k/',
#                          catalog='/Users/azib/Documents/open_source/nets2/catalogs/fakebinaries1k.txt',frac_balance=1,cadences=cadences)

# %%
# exocomets_extra = stella.FlareDataSet(fn_dir='/Users/azib/Documents/open_source/nets2/models/comets20k/',
#                          catalog='/Users/azib/Documents/open_source/nets2/catalogs/comets20k.txt',cadences=cadences,frac_balance=1)

# %%
# rbinaries = stella.FlareDataSet(fn_dir='/Users/azib/Documents/open_source/nets2/models/binaries-s7/',
#                          catalog='/Users/azib/Documents/open_source/nets2/catalogs/binaries-catalog-s7.txt',cadences=cadences,frac_balance=1)

# %%
# ds = stella.FlareDataSet(fn_dir='/Users/azib/Documents/open_source/nets2/models/comets10k-newmodel/',
#                          catalog='/Users/azib/Documents/open_source/nets2/catalogs/comets10k-newmodel.txt',cadences=cadences,training=0.8,validation=0.1,frac_balance=0.26 , merge_datasets=True,other_datasets = [exoplanets,fbinaries,rbinaries,exocomets_extra],other_datasets_labels = [2,3,4,1] )

# %%
ds = stella.FlareDataSet(fn_dir='/Users/azib/Documents/open_source/nets2/models/comets15k-cometcurve2/',
                         catalog='/Users/azib/Documents/open_source/nets2/catalogs/comets15k-cometcurve2.txt',cadences=cadences,training=0.8,validation=0.15,frac_balance=0.7,augment_portion=0.2)
# Out:
# Reading in training set files.
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15266/15266 [00:04<00:00, 3487.56it/s]
# Number of positive class training data: 10426
# Number of negative class training data: 9803
# Number of positive class validation data: 1955
# Number of negative class validation data: 1447
# Size of augmented data (training set only): 2085
# Class label (training): 0.0, Count: 9803
# Class label (training): 1.0, Count: 10426
# Class label (validation): 0, Count: 1447
# Class label (validation): 1, Count: 1955
# Total size of training set: 20229
# Total size of validation set: 3402
# Total size of test set: 1134
# Approximate class imbalance: -6.0

# %%
len(ds.train_data)
# Out:
# 4735

# %% [markdown]
# ## Training Data Plots

# %%
m = 46
ind_pc = np.where(ds.train_labels==1)[0] 
ind_nc = np.where(ds.train_labels!=1)[0] 
print(len(ind_pc),"positive class in training set")
print(len(ind_nc),"true negative class in training set")

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,3),
                               sharex=True, sharey=True)
ax1.plot(ds.train_data[ind_pc[m]], 'r')
ax1.set_title('Comet')
ax1.set_xlabel('Cadences')
ax2.plot(ds.train_data[ind_nc[m]], 'k')
ax2.set_title('No Comet')
ax2.set_xlabel('Cadences');
# Out:
# 3946 positive class in training set
# 789 true negative class in training set

# %% [markdown]
# ## Training Data Imbalance

# %%
print(f"{np.round(100 * len(ind_pc) / len(ind_nc))}% class imbalance")
print(len(ind_pc), "positive class")
print(len(ind_nc), "negative class")
# Out:
# 500.0% class imbalance
# 3946 positive class
# 789 negative class

# %% [markdown]
# ## Validation data plots

# %%
val_pc = np.where(ds.val_labels==1)[0] 
val_nc = np.where(ds.val_labels!=1)[0] 


fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,3),
                               sharex=True, sharey=True)
ax1.plot(ds.val_data[val_pc[1]], 'r')
ax1.set_title('Comet')
ax1.set_xlabel('Cadences')
ax2.plot(ds.val_data[val_nc[-1]], 'k')
ax2.set_title('No Comet')
ax2.set_xlabel('Cadences');

# %%
print(f"{np.round(100 * len(val_pc) / len(val_nc))}% class imbalance")
print(len(val_pc), "positive class")
print(len(val_nc), "negative class")
# Out:
# 123.0% class imbalance
# 1956 positive class
# 1596 negative class

# %%
# dsmodels = ds.train_data[ind_nc]

# num_sets = dsmodels.shape[0] // 100

# for set_index in range(num_sets):
#     start_index = set_index * 100
#     end_index = min((set_index + 1) * 100, dsmodels.shape[0])  # Ensure not to exceed the length of the data

#     # Create a new 10x10 grid of subplots for each set
#     fig, axs = plt.subplots(10, 10, figsize=(20, 20))

#     # Flatten the axes array for easier iteration
#     axs = axs.flatten()

#     # Iterate over the elements in the current set and plot each in the grid
#     for i in range(start_index, end_index):
#         plot_index = i % 100  # Calculate the index within the current grid
#         axs[plot_index].plot(dsmodels[i, :, 0])  # Assuming you want to plot the first dimension of your array
#         axs[plot_index].set_title(f"Plot {i}")  # Title for each subplot

#     # Hide any remaining empty subplots
#     for j in range(end_index - start_index, len(axs)):
#         axs[j].axis('off')

    
#     plt.tight_layout()  # Adjust layout
#     #plt.savefig(f'example-models{start_index}-{end_index}.png',dpi=200,bbox_inches='tight')
#     plt.show()  # Show the grid of plots
#     break

# %%
filter1 = 32
filter2 = 64
kernel_size1 = 7
kernel_size2 = 3
pool_size = 2
dropout = 0.1
dense = 512
l2val = 0.005
input_shape = (cadences, 1)
activation = 'relu'

# Define the model layers as a list
layers = [
    tf.keras.layers.Conv1D(
        filters=filter1,
        kernel_size=kernel_size1,
        activation=activation,
        padding="same",
        input_shape=input_shape,
        #kernel_regularizer=tf.keras.regularizers.l2(l2val)  # Optional: include if needed
    ),
    tf.keras.layers.MaxPooling1D(pool_size=pool_size),
    tf.keras.layers.Dropout(dropout),
    
    tf.keras.layers.Conv1D(
        filters=filter2,
        kernel_size=kernel_size2,
        activation=activation,
        padding="same",
        #kernel_regularizer=tf.keras.regularizers.l2(l2val)  # Optional: include if needed
    ),
    tf.keras.layers.MaxPooling1D(pool_size=pool_size),
    tf.keras.layers.Dropout(dropout),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(
        dense,
        activation=activation,
        #kernel_regularizer=tf.keras.regularizers.l2(l2val)  # Optional: include if needed
    ),
    tf.keras.layers.Dropout(dropout),
    tf.keras.layers.Dense(1, activation="sigmoid")
]

# %%
cnn = stella.ConvNN(output_dir='/Users/azib/Documents/open_source/nets2/cnn-models/',ds=ds,layers=layers)
SEED = [6]

# %%
#%tensorboard --logdir './logs'
cnn.train_models(seeds=SEED, epochs=150,batch_size=128,shuffle=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 240, 32)           256
#
#  max_pooling1d (MaxPooling1  (None, 120, 32)           0
#  D)
#
#  dropout (Dropout)           (None, 120, 32)           0
#
#  conv1d_1 (Conv1D)           (None, 120, 64)           6208
#
#  max_pooling1d_1 (MaxPoolin  (None, 60, 64)            0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 60, 64)            0
#
#  flatten (Flatten)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1973569 (7.53 MB)
# Trainable params: 1973569 (7.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.7115 - accuracy: 0.5004 - precision: 0.4938 - recall: 0.2866 - val_loss: 0.6956 - val_accuracy: 0.4493 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 0.0010
# Epoch 2/150
# 165/165 [==============================] - 9s 54ms/step - loss: 0.6933 - accuracy: 0.5012 - precision: 0.4965 - recall: 0.3931 - val_loss: 0.6938 - val_accuracy: 0.4496 - val_precision: 1.0000 - val_recall: 5.1125e-04 - lr: 0.0010
# Epoch 3/150
# 165/165 [==============================] - 6s 38ms/step - loss: 0.6931 - accuracy: 0.5026 - precision: 0.4975 - recall: 0.2709 - val_loss: 0.6932 - val_accuracy: 0.4538 - val_precision: 1.0000 - val_recall: 0.0082 - lr: 0.0010
# Epoch 4/150
# 165/165 [==============================] - 6s 36ms/step - loss: 0.6930 - accuracy: 0.5067 - precision: 0.5058 - recall: 0.2427 - val_loss: 0.6945 - val_accuracy: 0.4507 - val_precision: 1.0000 - val_recall: 0.0026 - lr: 0.0010
# Epoch 5/150
# 165/165 [==============================] - 6s 36ms/step - loss: 0.6931 - accuracy: 0.5018 - precision: 0.4970 - recall: 0.3616 - val_loss: 0.6938 - val_accuracy: 0.4527 - val_precision: 1.0000 - val_recall: 0.0061 - lr: 0.0010
# Epoch 6/150
# 165/165 [==============================] - 6s 36ms/step - loss: 0.6927 - accuracy: 0.5155 - precision: 0.5118 - recall: 0.5034 - val_loss: 0.6967 - val_accuracy: 0.4521 - val_precision: 1.0000 - val_recall: 0.0051 - lr: 0.0010
# Epoch 7/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.6917 - accuracy: 0.5187 - precision: 0.5213 - recall: 0.3654 - val_loss: 0.6859 - val_accuracy: 0.5507 - val_precision: 0.5507 - val_recall: 1.0000 - lr: 0.0010
# Epoch 8/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.6887 - accuracy: 0.5451 - precision: 0.5514 - recall: 0.4453 - val_loss: 0.6799 - val_accuracy: 0.6456 - val_precision: 0.9834 - val_recall: 0.3625 - lr: 0.0010
# Epoch 9/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.6634 - accuracy: 0.6094 - precision: 0.6215 - recall: 0.5438 - val_loss: 0.5864 - val_accuracy: 0.8803 - val_precision: 0.9824 - val_recall: 0.7970 - lr: 0.0010
# Epoch 10/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.5976 - accuracy: 0.6931 - precision: 0.7046 - recall: 0.6565 - val_loss: 0.4903 - val_accuracy: 0.7311 - val_precision: 0.9855 - val_recall: 0.5194 - lr: 0.0010
# Epoch 11/150
# 165/165 [==============================] - 6s 37ms/step - loss: 0.5293 - accuracy: 0.7517 - precision: 0.7580 - recall: 0.7337 - val_loss: 0.3733 - val_accuracy: 0.8857 - val_precision: 0.9826 - val_recall: 0.8067 - lr: 0.0010
# Epoch 12/150
# 165/165 [==============================] - 7s 40ms/step - loss: 0.4678 - accuracy: 0.7998 - precision: 0.8177 - recall: 0.7674 - val_loss: 0.2950 - val_accuracy: 0.9245 - val_precision: 0.9790 - val_recall: 0.8819 - lr: 0.0010
# Epoch 13/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.4315 - accuracy: 0.8127 - precision: 0.8242 - recall: 0.7911 - val_loss: 0.3223 - val_accuracy: 0.9550 - val_precision: 0.9751 - val_recall: 0.9422 - lr: 0.0010
# Epoch 14/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.3712 - accuracy: 0.8432 - precision: 0.8473 - recall: 0.8342 - val_loss: 0.2498 - val_accuracy: 0.9164 - val_precision: 0.9809 - val_recall: 0.8650 - lr: 0.0010
# Epoch 15/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.3312 - accuracy: 0.8629 - precision: 0.8686 - recall: 0.8527 - val_loss: 0.2516 - val_accuracy: 0.9344 - val_precision: 0.9762 - val_recall: 0.9029 - lr: 0.0010
# Epoch 16/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.3215 - accuracy: 0.8656 - precision: 0.8684 - recall: 0.8594 - val_loss: 0.2178 - val_accuracy: 0.9443 - val_precision: 0.9756 - val_recall: 0.9218 - lr: 0.0010
# Epoch 17/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.3072 - accuracy: 0.8768 - precision: 0.8803 - recall: 0.8699 - val_loss: 0.1611 - val_accuracy: 0.9564 - val_precision: 0.9772 - val_recall: 0.9427 - lr: 0.0010
# Epoch 18/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.2752 - accuracy: 0.8925 - precision: 0.8963 - recall: 0.8858 - val_loss: 0.1886 - val_accuracy: 0.9581 - val_precision: 0.9753 - val_recall: 0.9479 - lr: 0.0010
# Epoch 19/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.2508 - accuracy: 0.9062 - precision: 0.9104 - recall: 0.8995 - val_loss: 0.1578 - val_accuracy: 0.9631 - val_precision: 0.9740 - val_recall: 0.9586 - lr: 0.0010
# Epoch 20/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.2830 - accuracy: 0.8882 - precision: 0.8931 - recall: 0.8798 - val_loss: 0.1870 - val_accuracy: 0.9476 - val_precision: 0.9794 - val_recall: 0.9243 - lr: 0.0010
# Epoch 21/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.2679 - accuracy: 0.9002 - precision: 0.9065 - recall: 0.8908 - val_loss: 0.2284 - val_accuracy: 0.9679 - val_precision: 0.9689 - val_recall: 0.9729 - lr: 0.0010
# Epoch 22/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1974 - accuracy: 0.9327 - precision: 0.9340 - recall: 0.9301 - val_loss: 0.1297 - val_accuracy: 0.9685 - val_precision: 0.9772 - val_recall: 0.9652 - lr: 0.0010
# Epoch 23/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1979 - accuracy: 0.9307 - precision: 0.9343 - recall: 0.9253 - val_loss: 0.2121 - val_accuracy: 0.9459 - val_precision: 0.9778 - val_recall: 0.9228 - lr: 0.0010
# Epoch 24/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1958 - accuracy: 0.9330 - precision: 0.9361 - recall: 0.9282 - val_loss: 0.1172 - val_accuracy: 0.9707 - val_precision: 0.9715 - val_recall: 0.9755 - lr: 0.0010
# Epoch 25/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.2093 - accuracy: 0.9233 - precision: 0.9298 - recall: 0.9145 - val_loss: 0.1568 - val_accuracy: 0.9707 - val_precision: 0.9778 - val_recall: 0.9688 - lr: 0.0010
# Epoch 26/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1835 - accuracy: 0.9367 - precision: 0.9400 - recall: 0.9319 - val_loss: 0.1599 - val_accuracy: 0.9657 - val_precision: 0.9722 - val_recall: 0.9652 - lr: 0.0010
# Epoch 27/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1829 - accuracy: 0.9378 - precision: 0.9403 - recall: 0.9340 - val_loss: 0.1054 - val_accuracy: 0.9752 - val_precision: 0.9814 - val_recall: 0.9734 - lr: 0.0010
# Epoch 28/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1447 - accuracy: 0.9531 - precision: 0.9533 - recall: 0.9521 - val_loss: 0.1327 - val_accuracy: 0.9583 - val_precision: 0.9855 - val_recall: 0.9381 - lr: 0.0010
# Epoch 29/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1671 - accuracy: 0.9434 - precision: 0.9448 - recall: 0.9410 - val_loss: 0.1487 - val_accuracy: 0.9704 - val_precision: 0.9658 - val_recall: 0.9811 - lr: 0.0010
# Epoch 30/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1537 - accuracy: 0.9508 - precision: 0.9504 - recall: 0.9505 - val_loss: 0.1068 - val_accuracy: 0.9738 - val_precision: 0.9755 - val_recall: 0.9770 - lr: 0.0010
# Epoch 31/150
# 165/165 [==============================] - 6s 38ms/step - loss: 0.1670 - accuracy: 0.9449 - precision: 0.9471 - recall: 0.9415 - val_loss: 0.1172 - val_accuracy: 0.9696 - val_precision: 0.9873 - val_recall: 0.9571 - lr: 0.0010
# Epoch 32/150
# 165/165 [==============================] - 6s 38ms/step - loss: 0.1650 - accuracy: 0.9424 - precision: 0.9425 - recall: 0.9412 - val_loss: 0.1001 - val_accuracy: 0.9749 - val_precision: 0.9849 - val_recall: 0.9693 - lr: 0.0010
# Epoch 33/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1572 - accuracy: 0.9474 - precision: 0.9480 - recall: 0.9458 - val_loss: 0.0952 - val_accuracy: 0.9786 - val_precision: 0.9840 - val_recall: 0.9770 - lr: 0.0010
# Epoch 34/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1573 - accuracy: 0.9464 - precision: 0.9478 - recall: 0.9439 - val_loss: 0.1159 - val_accuracy: 0.9721 - val_precision: 0.9833 - val_recall: 0.9657 - lr: 0.0010
# Epoch 35/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1512 - accuracy: 0.9500 - precision: 0.9513 - recall: 0.9477 - val_loss: 0.2524 - val_accuracy: 0.9127 - val_precision: 0.9887 - val_recall: 0.8512 - lr: 0.0010
# Epoch 36/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1487 - accuracy: 0.9522 - precision: 0.9528 - recall: 0.9506 - val_loss: 0.1047 - val_accuracy: 0.9758 - val_precision: 0.9810 - val_recall: 0.9749 - lr: 0.0010
# Epoch 37/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1877 - accuracy: 0.9344 - precision: 0.9346 - recall: 0.9330 - val_loss: 0.1118 - val_accuracy: 0.9716 - val_precision: 0.9828 - val_recall: 0.9652 - lr: 0.0010
# Epoch 38/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1554 - accuracy: 0.9476 - precision: 0.9481 - recall: 0.9460 - val_loss: 0.1336 - val_accuracy: 0.9628 - val_precision: 0.9893 - val_recall: 0.9427 - lr: 0.0010
# Epoch 39/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1592 - accuracy: 0.9465 - precision: 0.9477 - recall: 0.9443 - val_loss: 0.0877 - val_accuracy: 0.9766 - val_precision: 0.9771 - val_recall: 0.9806 - lr: 0.0010
# Epoch 40/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1570 - accuracy: 0.9462 - precision: 0.9469 - recall: 0.9445 - val_loss: 0.0869 - val_accuracy: 0.9780 - val_precision: 0.9791 - val_recall: 0.9811 - lr: 0.0010
# Epoch 41/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1638 - accuracy: 0.9422 - precision: 0.9444 - recall: 0.9387 - val_loss: 0.1012 - val_accuracy: 0.9764 - val_precision: 0.9776 - val_recall: 0.9796 - lr: 0.0010
# Epoch 42/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1230 - accuracy: 0.9606 - precision: 0.9595 - recall: 0.9611 - val_loss: 0.1139 - val_accuracy: 0.9721 - val_precision: 0.9849 - val_recall: 0.9642 - lr: 0.0010
# Epoch 43/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1629 - accuracy: 0.9452 - precision: 0.9462 - recall: 0.9433 - val_loss: 0.0934 - val_accuracy: 0.9766 - val_precision: 0.9776 - val_recall: 0.9801 - lr: 0.0010
# Epoch 44/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1386 - accuracy: 0.9525 - precision: 0.9533 - recall: 0.9508 - val_loss: 0.1472 - val_accuracy: 0.9628 - val_precision: 0.9903 - val_recall: 0.9417 - lr: 0.0010
# Epoch 45/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1329 - accuracy: 0.9559 - precision: 0.9561 - recall: 0.9550 - val_loss: 0.0871 - val_accuracy: 0.9800 - val_precision: 0.9886 - val_recall: 0.9749 - lr: 0.0010
# Epoch 46/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1461 - accuracy: 0.9530 - precision: 0.9543 - recall: 0.9507 - val_loss: 0.0884 - val_accuracy: 0.9811 - val_precision: 0.9826 - val_recall: 0.9831 - lr: 0.0010
# Epoch 47/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1338 - accuracy: 0.9568 - precision: 0.9574 - recall: 0.9554 - val_loss: 0.1162 - val_accuracy: 0.9761 - val_precision: 0.9840 - val_recall: 0.9724 - lr: 0.0010
# Epoch 48/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1472 - accuracy: 0.9518 - precision: 0.9536 - recall: 0.9491 - val_loss: 0.1045 - val_accuracy: 0.9783 - val_precision: 0.9860 - val_recall: 0.9744 - lr: 0.0010
# Epoch 49/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1192 - accuracy: 0.9627 - precision: 0.9638 - recall: 0.9609 - val_loss: 0.0878 - val_accuracy: 0.9761 - val_precision: 0.9875 - val_recall: 0.9688 - lr: 0.0010
# Epoch 50/150
# 165/165 [==============================] - 7s 40ms/step - loss: 0.1377 - accuracy: 0.9547 - precision: 0.9564 - recall: 0.9521 - val_loss: 0.0794 - val_accuracy: 0.9811 - val_precision: 0.9831 - val_recall: 0.9826 - lr: 0.0010
# Epoch 51/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1424 - accuracy: 0.9520 - precision: 0.9525 - recall: 0.9505 - val_loss: 0.0835 - val_accuracy: 0.9794 - val_precision: 0.9851 - val_recall: 0.9775 - lr: 0.0010
# Epoch 52/150
# 165/165 [==============================] - 6s 36ms/step - loss: 0.1303 - accuracy: 0.9577 - precision: 0.9581 - recall: 0.9565 - val_loss: 0.0808 - val_accuracy: 0.9806 - val_precision: 0.9831 - val_recall: 0.9816 - lr: 0.0010
# Epoch 53/150
# 165/165 [==============================] - 7s 41ms/step - loss: 0.1289 - accuracy: 0.9570 - precision: 0.9575 - recall: 0.9557 - val_loss: 0.1071 - val_accuracy: 0.9769 - val_precision: 0.9728 - val_recall: 0.9857 - lr: 0.0010
# Epoch 54/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1775 - accuracy: 0.9395 - precision: 0.9417 - recall: 0.9360 - val_loss: 0.1060 - val_accuracy: 0.9755 - val_precision: 0.9684 - val_recall: 0.9877 - lr: 0.0010
# Epoch 55/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1271 - accuracy: 0.9587 - precision: 0.9578 - recall: 0.9590 - val_loss: 0.1001 - val_accuracy: 0.9772 - val_precision: 0.9790 - val_recall: 0.9796 - lr: 0.0010
# Epoch 56/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1399 - accuracy: 0.9528 - precision: 0.9542 - recall: 0.9505 - val_loss: 0.0884 - val_accuracy: 0.9780 - val_precision: 0.9830 - val_recall: 0.9770 - lr: 0.0010
# Epoch 57/150
# 165/165 [==============================] - 8s 47ms/step - loss: 0.1197 - accuracy: 0.9611 - precision: 0.9607 - recall: 0.9609 - val_loss: 0.0912 - val_accuracy: 0.9766 - val_precision: 0.9805 - val_recall: 0.9770 - lr: 0.0010
# Epoch 58/150
# 165/165 [==============================] - 7s 43ms/step - loss: 0.1418 - accuracy: 0.9542 - precision: 0.9550 - recall: 0.9525 - val_loss: 0.1016 - val_accuracy: 0.9772 - val_precision: 0.9742 - val_recall: 0.9847 - lr: 0.0010
# Epoch 59/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1271 - accuracy: 0.9600 - precision: 0.9601 - recall: 0.9592 - val_loss: 0.1522 - val_accuracy: 0.9583 - val_precision: 0.9902 - val_recall: 0.9335 - lr: 0.0010
# Epoch 60/150
# 165/165 [==============================] - 6s 37ms/step - loss: 0.1475 - accuracy: 0.9508 - precision: 0.9513 - recall: 0.9495 - val_loss: 0.0876 - val_accuracy: 0.9792 - val_precision: 0.9801 - val_recall: 0.9821 - lr: 0.0010
# Epoch 61/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1432 - accuracy: 0.9516 - precision: 0.9529 - recall: 0.9493 - val_loss: 0.0971 - val_accuracy: 0.9761 - val_precision: 0.9810 - val_recall: 0.9755 - lr: 0.0010
# Epoch 62/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1354 - accuracy: 0.9518 - precision: 0.9504 - recall: 0.9525 - val_loss: 0.0872 - val_accuracy: 0.9809 - val_precision: 0.9866 - val_recall: 0.9785 - lr: 0.0010
# Epoch 63/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1540 - accuracy: 0.9463 - precision: 0.9469 - recall: 0.9447 - val_loss: 0.1009 - val_accuracy: 0.9800 - val_precision: 0.9861 - val_recall: 0.9775 - lr: 0.0010
# Epoch 64/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1432 - accuracy: 0.9515 - precision: 0.9535 - recall: 0.9484 - val_loss: 0.1118 - val_accuracy: 0.9724 - val_precision: 0.9869 - val_recall: 0.9627 - lr: 0.0010
# Epoch 65/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1140 - accuracy: 0.9628 - precision: 0.9625 - recall: 0.9625 - val_loss: 0.0787 - val_accuracy: 0.9789 - val_precision: 0.9831 - val_recall: 0.9785 - lr: 0.0010
# Epoch 66/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1813 - accuracy: 0.9348 - precision: 0.9363 - recall: 0.9318 - val_loss: 0.0764 - val_accuracy: 0.9817 - val_precision: 0.9826 - val_recall: 0.9842 - lr: 0.0010
# Epoch 67/150
# 165/165 [==============================] - 5s 31ms/step - loss: 0.1425 - accuracy: 0.9518 - precision: 0.9528 - recall: 0.9499 - val_loss: 0.0851 - val_accuracy: 0.9794 - val_precision: 0.9772 - val_recall: 0.9857 - lr: 0.0010
# Epoch 68/150
# 165/165 [==============================] - 5s 31ms/step - loss: 0.1086 - accuracy: 0.9654 - precision: 0.9663 - recall: 0.9640 - val_loss: 0.1272 - val_accuracy: 0.9654 - val_precision: 0.9904 - val_recall: 0.9463 - lr: 0.0010
# Epoch 69/150
# 165/165 [==============================] - 5s 31ms/step - loss: 0.1338 - accuracy: 0.9562 - precision: 0.9562 - recall: 0.9554 - val_loss: 0.0847 - val_accuracy: 0.9814 - val_precision: 0.9768 - val_recall: 0.9898 - lr: 0.0010
# Epoch 70/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1344 - accuracy: 0.9547 - precision: 0.9550 - recall: 0.9536 - val_loss: 0.1212 - val_accuracy: 0.9673 - val_precision: 0.9909 - val_recall: 0.9494 - lr: 0.0010
# Epoch 71/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1244 - accuracy: 0.9588 - precision: 0.9594 - recall: 0.9575 - val_loss: 0.0784 - val_accuracy: 0.9803 - val_precision: 0.9876 - val_recall: 0.9765 - lr: 0.0010
# Epoch 72/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1168 - accuracy: 0.9601 - precision: 0.9582 - recall: 0.9615 - val_loss: 0.1089 - val_accuracy: 0.9699 - val_precision: 0.9884 - val_recall: 0.9565 - lr: 0.0010
# Epoch 73/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1250 - accuracy: 0.9592 - precision: 0.9602 - recall: 0.9575 - val_loss: 0.0965 - val_accuracy: 0.9820 - val_precision: 0.9807 - val_recall: 0.9867 - lr: 0.0010
# Epoch 74/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1299 - accuracy: 0.9554 - precision: 0.9563 - recall: 0.9537 - val_loss: 0.1069 - val_accuracy: 0.9766 - val_precision: 0.9742 - val_recall: 0.9836 - lr: 0.0010
# Epoch 75/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1203 - accuracy: 0.9603 - precision: 0.9628 - recall: 0.9571 - val_loss: 0.0854 - val_accuracy: 0.9789 - val_precision: 0.9816 - val_recall: 0.9801 - lr: 0.0010
# Epoch 76/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1369 - accuracy: 0.9528 - precision: 0.9528 - recall: 0.9520 - val_loss: 0.0849 - val_accuracy: 0.9780 - val_precision: 0.9845 - val_recall: 0.9755 - lr: 0.0010
# Epoch 77/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1447 - accuracy: 0.9501 - precision: 0.9500 - recall: 0.9494 - val_loss: 0.0991 - val_accuracy: 0.9800 - val_precision: 0.9796 - val_recall: 0.9842 - lr: 0.0010
# Epoch 78/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1641 - accuracy: 0.9396 - precision: 0.9428 - recall: 0.9349 - val_loss: 0.1041 - val_accuracy: 0.9766 - val_precision: 0.9870 - val_recall: 0.9703 - lr: 0.0010
# Epoch 79/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1409 - accuracy: 0.9521 - precision: 0.9542 - recall: 0.9490 - val_loss: 0.2746 - val_accuracy: 0.9071 - val_precision: 0.9903 - val_recall: 0.8395 - lr: 0.0010
# Epoch 80/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1131 - accuracy: 0.9626 - precision: 0.9637 - recall: 0.9608 - val_loss: 0.0788 - val_accuracy: 0.9814 - val_precision: 0.9778 - val_recall: 0.9888 - lr: 0.0010
# Epoch 81/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1268 - accuracy: 0.9572 - precision: 0.9564 - recall: 0.9572 - val_loss: 0.0918 - val_accuracy: 0.9772 - val_precision: 0.9885 - val_recall: 0.9698 - lr: 0.0010
# Epoch 82/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1391 - accuracy: 0.9519 - precision: 0.9537 - recall: 0.9491 - val_loss: 0.1250 - val_accuracy: 0.9626 - val_precision: 0.9867 - val_recall: 0.9448 - lr: 0.0010
# Epoch 83/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1257 - accuracy: 0.9573 - precision: 0.9603 - recall: 0.9534 - val_loss: 0.2661 - val_accuracy: 0.9153 - val_precision: 0.9876 - val_recall: 0.8569 - lr: 0.0010
# Epoch 84/150
# 165/165 [==============================] - 6s 38ms/step - loss: 0.1492 - accuracy: 0.9467 - precision: 0.9479 - recall: 0.9446 - val_loss: 0.1434 - val_accuracy: 0.9597 - val_precision: 0.9908 - val_recall: 0.9356 - lr: 0.0010
# Epoch 85/150
# 165/165 [==============================] - 7s 41ms/step - loss: 0.1364 - accuracy: 0.9530 - precision: 0.9544 - recall: 0.9506 - val_loss: 0.0798 - val_accuracy: 0.9786 - val_precision: 0.9865 - val_recall: 0.9744 - lr: 0.0010
# Epoch 86/150
# 165/165 [==============================] - 6s 36ms/step - loss: 0.1344 - accuracy: 0.9542 - precision: 0.9560 - recall: 0.9515 - val_loss: 0.0740 - val_accuracy: 0.9800 - val_precision: 0.9846 - val_recall: 0.9790 - lr: 0.0010
# Epoch 87/150
# 165/165 [==============================] - 7s 44ms/step - loss: 0.1093 - accuracy: 0.9634 - precision: 0.9635 - recall: 0.9628 - val_loss: 0.0747 - val_accuracy: 0.9800 - val_precision: 0.9831 - val_recall: 0.9806 - lr: 0.0010
# Epoch 88/150
# 165/165 [==============================] - 7s 43ms/step - loss: 0.1730 - accuracy: 0.9369 - precision: 0.9395 - recall: 0.9329 - val_loss: 0.1655 - val_accuracy: 0.9688 - val_precision: 0.9812 - val_recall: 0.9617 - lr: 0.0010
# Epoch 89/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1360 - accuracy: 0.9539 - precision: 0.9567 - recall: 0.9502 - val_loss: 0.0692 - val_accuracy: 0.9837 - val_precision: 0.9817 - val_recall: 0.9888 - lr: 0.0010
# Epoch 90/150
# 165/165 [==============================] - 5s 32ms/step - loss: 0.1108 - accuracy: 0.9634 - precision: 0.9622 - recall: 0.9641 - val_loss: 0.0712 - val_accuracy: 0.9800 - val_precision: 0.9846 - val_recall: 0.9790 - lr: 0.0010
# Epoch 91/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1397 - accuracy: 0.9503 - precision: 0.9523 - recall: 0.9473 - val_loss: 0.0619 - val_accuracy: 0.9828 - val_precision: 0.9856 - val_recall: 0.9831 - lr: 0.0010
# Epoch 92/150
# 165/165 [==============================] - 6s 39ms/step - loss: 0.1437 - accuracy: 0.9487 - precision: 0.9507 - recall: 0.9457 - val_loss: 0.1051 - val_accuracy: 0.9733 - val_precision: 0.9890 - val_recall: 0.9622 - lr: 0.0010
# Epoch 93/150
# 165/165 [==============================] - 7s 42ms/step - loss: 0.1510 - accuracy: 0.9451 - precision: 0.9439 - recall: 0.9455 - val_loss: 0.0672 - val_accuracy: 0.9811 - val_precision: 0.9831 - val_recall: 0.9826 - lr: 0.0010
# Epoch 94/150
# 165/165 [==============================] - 7s 44ms/step - loss: 0.1109 - accuracy: 0.9627 - precision: 0.9639 - recall: 0.9608 - val_loss: 0.1023 - val_accuracy: 0.9724 - val_precision: 0.9900 - val_recall: 0.9596 - lr: 0.0010
# Epoch 95/150
# 165/165 [==============================] - 7s 44ms/step - loss: 0.2195 - accuracy: 0.9136 - precision: 0.9131 - recall: 0.9126 - val_loss: 0.1134 - val_accuracy: 0.9685 - val_precision: 0.9863 - val_recall: 0.9560 - lr: 0.0010
# Epoch 96/150
# 165/165 [==============================] - 6s 33ms/step - loss: 0.1287 - accuracy: 0.9553 - precision: 0.9587 - recall: 0.9508 - val_loss: 0.0741 - val_accuracy: 0.9820 - val_precision: 0.9846 - val_recall: 0.9826 - lr: 0.0010
# Epoch 97/150
# 165/165 [==============================] - 7s 40ms/step - loss: 0.1198 - accuracy: 0.9587 - precision: 0.9585 - recall: 0.9583 - val_loss: 0.0689 - val_accuracy: 0.9823 - val_precision: 0.9832 - val_recall: 0.9847 - lr: 0.0010
# Epoch 98/150
# 165/165 [==============================] - 6s 35ms/step - loss: 0.1510 - accuracy: 0.9454 - precision: 0.9495 - recall: 0.9399 - val_loss: 0.1179 - val_accuracy: 0.9775 - val_precision: 0.9796 - val_recall: 0.9796 - lr: 0.0010
# Epoch 99/150
# 165/165 [==============================] - 5s 33ms/step - loss: 0.1706 - accuracy: 0.9390 - precision: 0.9413 - recall: 0.9354 - val_loss: 0.0666 - val_accuracy: 0.9814 - val_precision: 0.9851 - val_recall: 0.9811 - lr: 0.0010
# Epoch 100/150
# 165/165 [==============================] - 7s 41ms/step - loss: 0.1615 - accuracy: 0.9411 - precision: 0.9429 - recall: 0.9382 - val_loss: 0.0903 - val_accuracy: 0.9783 - val_precision: 0.9811 - val_recall: 0.9796 - lr: 0.0010
# Epoch 101/150
# 165/165 [==============================] - 6s 37ms/step - loss: 0.1585 - accuracy: 0.9436 - precision: 0.9487 - recall: 0.9369 - val_loss: 0.1084 - val_accuracy: 0.9724 - val_precision: 0.9905 - val_recall: 0.9591 - lr: 0.0010
# Epoch 102/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1097 - accuracy: 0.9634 - precision: 0.9652 - recall: 0.9608 - val_loss: 0.0610 - val_accuracy: 0.9837 - val_precision: 0.9812 - val_recall: 0.9893 - lr: 0.0010
# Epoch 103/150
# 165/165 [==============================] - 6s 37ms/step - loss: 0.1253 - accuracy: 0.9573 - precision: 0.9591 - recall: 0.9546 - val_loss: 0.0683 - val_accuracy: 0.9840 - val_precision: 0.9812 - val_recall: 0.9898 - lr: 0.0010
# Epoch 104/150
# 165/165 [==============================] - 6s 37ms/step - loss: 0.1362 - accuracy: 0.9522 - precision: 0.9557 - recall: 0.9476 - val_loss: 0.1782 - val_accuracy: 0.9583 - val_precision: 0.9839 - val_recall: 0.9397 - lr: 0.0010
# Epoch 105/150
# 165/165 [==============================] - 6s 39ms/step - loss: 0.1346 - accuracy: 0.9529 - precision: 0.9561 - recall: 0.9486 - val_loss: 0.1025 - val_accuracy: 0.9786 - val_precision: 0.9850 - val_recall: 0.9760 - lr: 0.0010
# Epoch 106/150
# 165/165 [==============================] - 7s 41ms/step - loss: 0.1398 - accuracy: 0.9505 - precision: 0.9513 - recall: 0.9488 - val_loss: 0.0811 - val_accuracy: 0.9794 - val_precision: 0.9881 - val_recall: 0.9744 - lr: 0.0010
# Epoch 107/150
# 165/165 [==============================] - 6s 39ms/step - loss: 0.1305 - accuracy: 0.9549 - precision: 0.9587 - recall: 0.9501 - val_loss: 0.1193 - val_accuracy: 0.9772 - val_precision: 0.9685 - val_recall: 0.9908 - lr: 0.0010
# Epoch 108/150
# 165/165 [==============================] - 6s 38ms/step - loss: 0.1382 - accuracy: 0.9527 - precision: 0.9553 - recall: 0.9490 - val_loss: 0.0815 - val_accuracy: 0.9778 - val_precision: 0.9901 - val_recall: 0.9693 - lr: 0.0010
# Epoch 109/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1107 - accuracy: 0.9610 - precision: 0.9625 - recall: 0.9588 - val_loss: 0.0954 - val_accuracy: 0.9761 - val_precision: 0.9906 - val_recall: 0.9657 - lr: 0.0010
# Epoch 110/150
# 165/165 [==============================] - 6s 34ms/step - loss: 0.1110 - accuracy: 0.9630 - precision: 0.9645 - recall: 0.9607 - val_loss: 0.0751 - val_accuracy: 0.9831 - val_precision: 0.9837 - val_recall: 0.9857 - lr: 0.0010
# Epoch 111/150
#  54/165 [========>.....................] - ETA: 3s - loss: 0.1066 - accuracy: 0.9648 - precision: 0.9655 - recall: 0.9635

# %%
from matplotlib import cm
import matplotlib.colors as mcolors
import numpy as np

if type(SEED) == list:
    for seeds in SEED:
        # Create a custom colormap
        custom_cmap = mcolors.ListedColormap(['yellow', 'darkblue', 'red','cyan'])

        fig, axes = plt.subplots(2, 2, figsize=(13,8))
        formatted_seed = f'{seeds:04}'

        # Plot ground truth
        sc = axes[0, 0].scatter(cnn.val_pred_table['tpeak'], cnn.val_pred_table[f'pred_s{formatted_seed}'],
                                c=cnn.val_pred_table['labels'], cmap=custom_cmap, label=f'Seed {formatted_seed}',s=10)
        axes[0, 0].set_xlabel('Tpeak [BJD - 2457000]')
        axes[0, 0].set_ylabel('Probability of Exocomet')
        axes[0,0].set_title('Probabilities (with the original labels)')
        plt.colorbar(sc, ax=axes[0, 0], ticks=np.arange(4), boundaries=np.arange(4+1)-0.5)

        # Plot loss
        axes[1, 1].plot(cnn.history_table[f'loss_s{formatted_seed}'], label=f'Training Seed {formatted_seed}', lw=3)
        axes[1, 1].plot(cnn.history_table[f'val_loss_s{formatted_seed}'], label=f'Validation Seed {formatted_seed}', lw=3)
        axes[1, 1].set_xlabel('Epochs')
        axes[1, 1].set_ylabel('Loss')
        axes[1,1].set_title('Loss')
        axes[1, 1].legend()

        # Plot accuracy
        axes[1, 0].plot(cnn.history_table[f'accuracy_s{formatted_seed}'], label=f'Training Seed {formatted_seed}', lw=3)
        axes[1, 0].plot(cnn.history_table[f'val_accuracy_s{formatted_seed}'], label=f'Validation Seed {formatted_seed}', lw=3)
        axes[1, 0].set_xlabel('Epochs')
        axes[1, 0].set_ylabel('Accuracy')
        axes[1, 0].set_title('Accuracy')
        axes[1, 0].legend()

        # Plot ground truth (gt)
        sc2 = axes[0, 1].scatter(cnn.val_pred_table['tpeak'], cnn.val_pred_table[f'pred_s{formatted_seed}'],
                                 c=cnn.val_pred_table['gt'], label=f'Seed {formatted_seed}')
        axes[0, 1].set_xlabel('Tpeak [BJD - 2457000]')
        axes[0, 1].set_ylabel('Probability of Exocomet')
        axes[0,1].set_title('Probabilities')
        plt.colorbar(sc2, ax=axes[0, 1])#, ticks=np.arange(2)#, boundaries=np.arange(2)-0.5)
    
        plt.tight_layout()
        plt.savefig(f'../metrics-{SEED}.png',dpi=300,bbox_inches='tight')
        plt.show()

# %% [markdown]
# Colour plot with SNR value

# %% [markdown]
# ---

# %% [markdown]
# ## Predict on Real Lightcurves

# %%
import sys
sys.path.insert(1,'/Users/azib/Documents/open_source/nets2/stella')
sys.path.insert(1,'/Users/azib/Documents/open_source/nets2/scripts')
from utils import *
import lightkurve as lk
import os
import tqdm

# %%
files = glob.glob('../272-candidates-npy/*.npy')
np.random.shuffle(files)

# %%
files2 = glob.glob('../models/comets10k-cometcurve2/*.npy')
np.random.shuffle(files2)

# %%
modelname = f'../cnn-models/ensemble_s0005_i0150_b{frac_balance}.h5'

# %%
lc = lk.search_lightcurve('Beta Pic',mission='TESS',sector=6)[1].download()

# %%
cnn.predict(modelname=modelname,
            times=lc.time.value,
            fluxes=lc.flux.value/np.nanmedian(lc.flux.value),
            errs=lc.flux_err.value)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.60it/s]

# %%
plt.figure(figsize=(14,4))
plt.scatter(cnn.predict_time[0], cnn.predict_flux[0],
            c=cnn.predictions[0], vmin=0, vmax=1)
plt.colorbar(label='Probability of Flare')
#plt.axvline(cnn.predict_time[0][np.argmax(cnn.predictions)],color='red',linestyle='--',zorder=1)
plt.xlabel('Time [BJD-2457000]')
plt.ylabel('Normalized Flux')
# Out:
# Text(0, 0.5, 'Normalized Flux')

# %%
fig, ax = plt.subplots(3, 6, figsize=(25, 10))

for i, a in enumerate(ax.flatten()):
    try:
        f = np.load(files[i],allow_pickle=True)
        cnn.predict(modelname='../cnn-models/ensemble_s0005_i0150_b0.67.h5',
                    times=f[0],
                    fluxes=f[1],
                    errs=f[2])
        a.scatter(cnn.predict_time[0], cnn.predict_flux[0],
                  c=cnn.predictions[0], s=2, vmin=0, vmax=1)
        plt.show()
    except:
        continue
# Out:
#   0%|                                                                                                                                                  | 0/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.19it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.37it/s]
#   0%|                                                                                                                                                  | 0/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.06it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.47it/s]
#   0%|                                                                                                                                                  | 0/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.10it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.13it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.09it/s]

# %%
fig, ax = plt.subplots(3, 4, figsize=(25, 10))

for i, a in enumerate(ax.flatten()):
    try:
        f = np.load(files[i],allow_pickle=True)
        cnn.predict(modelname='../cnn-models/ensemble_s0005_i0150_b0.67.h5',
                    times=f[0],
                    fluxes=f[1][::-1],
                    errs=f[2])
        a.scatter(cnn.predict_time[0], cnn.predict_flux[0],
                  c=cnn.predictions[0], s=2, vmin=0, vmax=1, cmap='magma')
        plt.show()
    except:
        continue
# Out:
#   0%|                                                                                                                                                  | 0/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  5.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.39it/s]
#   0%|                                                                                                                                                  | 0/1 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.42it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.39it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  7.00it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.35it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.54it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  6.50it/s]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## CNN from scratch
