# %% [markdown]
# # Injection Recovery plots in the parameter space

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import matplotlib.image as mpimg

# %%
files = glob.glob('../exo9/injected-skew_-1-duration-0.10-snr-11/*')
files[0:2]
# Out:
# ['../exo9/injected-skew_-1-duration-0.10-snr-11/exocomet_model_148945534_sector07.npy',
#  '../exo9/injected-skew_-1-duration-0.10-snr-11/exocomet_model_173509332_sector07.npy']

# %%
img = mpimg.imread('../recovery-plot-time-and-ind-cond-all-wider-window.png')

# Display the image
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.show()

# %%
for i in files[0:10]:
    time, flux, error, _  = np.load(i)
    plt.plot(time,flux)
    plt.show()
